# %% [markdown]
# # 10. Empty Value

# %%
import pandas as pd
df = pd.read_excel('score.xlsx', index_col='Sib. #')
df
# Out:
#           name school  height  English  Math  Science SWskills
# Sib. #
# 1st      Sally  Biola     157       97    89       88      C++
# 2nd      David    UCI     173       78   100       98   Python
# 3rd     Daniel   Navy     175       95    78       94     Java
# 4th      Peter  Emery     130      100    97       97    Swift

# %% [markdown]
# ## Fill Data (fillna) inplace = True to Set it

# %%
df.fillna('') # fill NaN with empty string
# Out:
#           name school  height  English  Math  Science SWskills
# Sib. #
# 1st      Sally  Biola     157       97    89       88      C++
# 2nd      David    UCI     173       78   100       98   Python
# 3rd     Daniel   Navy     175       95    78       94     Java
# 4th      Peter  Emery     130      100    97       97    Swift

# %%
import numpy as np
df['school'] = np.nan # set all the school data to NaN
df
# Out:
#           name  school  height  English  Math  Science SWskills
# Sib. #
# 1st      Sally     NaN     157       97    89       88      C++
# 2nd      David     NaN     173       78   100       98   Python
# 3rd     Daniel     NaN     175       95    78       94     Java
# 4th      Peter     NaN     130      100    97       97    Swift

# %%
import pandas as pd
df = pd.read_excel('score.xlsx', index_col='Sib. #')
df
# Out:
#           name school  height  English  Math  Science SWskills
# Sib. #
# 1st      Sally  Biola     157       97    89       88      C++
# 2nd      David    UCI     173       78   100       98   Python
# 3rd     Daniel   Navy     175       95    78       94     Java
# 4th      Peter  Emery     130      100    97       97    Swift

# %%
df['SWskills'].fillna('') # fill NaN with empty sting only for SWskills
# Out:
# Sib. #
# 1st       C++
# 2nd    Python
# 3rd      Java
# 4th     Swift
# Name: SWskills, dtype: object

# %% [markdown]
# ## Delete NaN (dropna)

# %%
df.dropna() # drop row that contains NaN
# Out:
#           name school  height  English  Math  Science SWskills
# Sib. #
# 1st      Sally  Biola     157       97    89       88      C++
# 2nd      David    UCI     173       78   100       98   Python
# 3rd     Daniel   Navy     175       95    78       94     Java
# 4th      Peter  Emery     130      100    97       97    Swift

# %% [markdown]
# - axis : index or columns
# - how : any or all

# %%
df.dropna(axis='index', how='any')
